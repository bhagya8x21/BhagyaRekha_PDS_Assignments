# %%
import pandas as pd
#importing the raw data

# %% [markdown]
# **Stage 1: Data Collection & Organization**

# %% [markdown]
# In this stage,I gathered, organizeed, and documented the raw data. This raw data is stored without modification to ensure the reproducibility of the analysis.

# %%
df = pd.read_csv('/content/data_raw/frailty.csv')


df.head()
# Out:
#    Height (Inches)   Weight (Pounds)   Age   Grip strength  Frailty
# 0              65.8               112    30              30        N
# 1              71.5               136    19              31        N
# 2              69.4               153    45              29        N
# 3              68.2               142    22              28        Y
# 4              67.8               144    29              24        Y

# %%
df.columns = df.columns.str.strip()

# %%
df.rename(columns = {'Height (Inches)':'height',
                       'Weight (Pounds)':'weight',
                       'Age':'age',
                        'Grip strength':'grip_strength',
                         'Frailty':'frailty'}, inplace = True)
df.frailty=df.frailty.map(dict(Y=1, N=0))

# %%
df.head()
# Out:
#    height  weight  age  grip_strength  frailty
# 0    65.8     112   30             30        0
# 1    71.5     136   19             31        0
# 2    69.4     153   45             29        0
# 3    68.2     142   22             28        1
# 4    67.8     144   29             24        1

# %% [markdown]
# **Stage 2: Data Processing & Cleaning**

# %% [markdown]
# In this stage, we process and clean the data. This could include dealing with missing values, normalizing, encoding categorical variables, etc.

# %%
df.to_csv('/content/data_clean/clean_frailty.csv')
